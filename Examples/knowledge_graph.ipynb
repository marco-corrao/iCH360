# %% [markdown]
# # Using the *i*CH360 knowledge graph

# %% [markdown]
# ## Introduction
# In a metabolic model, the the path connecting a biochemical reaction to its associated genes typically encounters a number of intermediate entities, including enzymes and their protein suunits, protein activators, prtoein cofactors, and many others.  The *i*CH360 knowledge graph is a graph data strucuture that enhances and support the stoichiometric model by providing an explicit representation of the intermediate biological entities and the relationship connecting them. The graph was assembled based on data retrieved from the EcoCyc database, which was then manually curated, extended, and annotated based on available literature.
#
# In the graph, nodes represent biological entities (reactions, proteins, genes, compounds) and edges denote (potentially quantitative) relationships between them. For example A reaction may be connected to a protein by a *catalysis* edge, indicating that the protein is an enzyme for that reaction. Similarly, a protein may be connected to another protein by a *subunit composition* relationship, implying that the latter protein is a subunit of the former. you can read more about the graph and its nodes/edge types in `Knowledge_graph/Knowledge_graph/knowledge_graph.md`.
#
#
# In this tutorial, we demonstrate how to load the graph, inspect it, and visualise relevant parts of it. We will use the package NetworkX to manipulate the graph, and the gravis package (https://github.com/robert-haas/gravis) for interactive visualisation.

# %% [markdown]
# ## Importing the required packages

# %%
import networkx as nx #for graph manipulation
import gravis #for interactive visualisation

# %% [markdown]
# ## Loading the graph
# We will load the graph using the `GML` (Graph Modelling Language) file in this repository.

# %%
ich360_graph=nx.read_gml('../Knowledge_Graph/ich360_graph.gml')

# %% [markdown]
# ## Inspecting nodes and their attributes

# %% [markdown]
# The object we just created is a directed graph (meaning edges have defined directionality). Let's inspect inspect its nodes:

# %%
ich360_graph.nodes
# Out:
# NodeView(('bigg:NDPK5', 'ADENYL-KIN-MONOMER', 'NUCLEOSIDE-DIP-KIN-MONOMER', 'NUCLEOSIDE-DIP-KIN-CPLX', 'bigg:SHK3Dr', 'AROE-MONOMER', 'bigg:NDPK6', 'bigg:NDPK8', 'bigg:DHORTS', 'DIHYDROOROT-MONOMER', 'DIHYDROOROT-CPLX', 'bigg:OMPDC', 'OROTPDECARB-MONOMER', 'OROTPDECARB-CPLX', 'bigg:G5SD', 'GLUTSEMIALDEHYDROG-MONOMER', 'GLUTSEMIALDEHYDROG-CPLX', 'bigg:CS', 'CITSYN-MONOMER', 'CITRATE-SI-SYNTHASE', 'bigg:ICDHyr', 'ISOCITDEH-SUBUNIT', 'ISOCITHASE-CPLX', 'bigg:ACALD', 'MHPF-MONOMER', 'ADHE-MONOMER', 'ADHE-CPLX', 'G7285-MONOMER', 'bigg:PPA', 'ALKAPHOSPHA-MONOMER', 'ALKAPHOSPHA-CPLX', 'INORGPYROPHOSPHAT-MONOMER', 'CPLX0-243', 'bigg:PPCK', 'PEPCARBOXYKIN-MONOMER', 'bigg:ME1', 'MALIC-NAD-MONOMER', 'MALIC-NAD-CPLX', 'bigg:ALATA_L', 'G7242-MONOMER', 'CPLX0-7887', 'G7184-MONOMER', 'CPLX0-7888', 'bigg:XYLK', 'XYLULOKIN-MONOMER', 'CPLX0-7466', 'bigg:RBK', 'RIBOKIN-MONOMER', 'CPLX0-7647', 'bigg:GLYK', 'GLYCEROL-KIN-MONOMER', 'GLYCEROL-KIN-CPLX', 'bigg:ASPTA', 'ASPAMINOTRANS-MONOMER', 'ASPAMINOTRANS-DIMER', 'bigg:FBP', 'EG11245-MONOMER', 'CPLX0-7776', 'EG11239-MONOMER', 'EG11517-MONOMER', 'CPLX0-303', 'F16B-MONOMER', 'F16B-CPLX', 'bigg:PYK', 'PKI-MONOMER', 'PKI-COMPLEX', 'PKII-MONOMER', 'PKII-CPLX', 'bigg:GTHOr', 'GLUTATHIONE-REDUCT-NADPH-MONOMER', 'GLUTATHIONE-REDUCT-NADPH-CPLX', 'bigg:ILETA', 'BRANCHED-CHAINAMINOTRANSFER-MONOMER', 'BRANCHED-CHAINAMINOTRANSFER-CPLX', 'bigg:DHORD5', 'DIHYDROOROTOX-MONOMER', 'bigg:VALTA', 'bigg:IPPMIb', 'LEUC-MONOMER', 'LEUD-MONOMER', '3-ISOPROPYLMALISOM-CPLX', 'bigg:ORPT', 'OROPRIBTRANS-MONOMER', 'OROPRIBTRANS-CPLX', 'bigg:ACHBS', 'SMALLILVM-MONOMER', 'ACETOLACTSYNII-CPLX', 'LARGEILVB-MONOMER', 'SMALLILVN-MONOMER', 'ACETOLACTSYNI-CPLX', 'ACETOLACTSYNIII-ICHAIN-MONOMER', 'ACETOLACTSYNIII-HCHAIN-MONOMER', 'ACETOLACTSYNIII-CPLX', 'bigg:DHAD2', 'DIHYDROXYACIDDEHYDRAT-MONOMER', 'DIHYDROXYACIDDEHYDRAT-CPLX', 'bigg:ACLS', 'bigg:TRPS2', 'TRYPSYN-BPROTEIN', 'CPLX0-2401', 'bigg:PSCVT', 'AROA-MONOMER', 'bigg:PFL', 'PYRUVFORMLY-MONOMER', 'PYRUVFORMLY-INACTIVE-CPLX', 'PYRUVFORMLY-CPLX', 'KETOBUTFORMLY-INACT-MONOMER', 'KETOBUTFORMLY-MONOMER', 'EG11784-MONOMER', 'CPLX0-9871', 'bigg:ANS', 'ANTHRANSYNCOMPI-MONOMER', 'ANTHRANSYNCOMPII-MONOMER', 'ANTHRANSYN-CPLX', 'bigg:FRD2', 'FUM-FLAVO', 'FUM-FE-S', 'FUM-MEMB1', 'FUM-MEMB2', 'FUMARATE-REDUCTASE', 'bigg:ANPRT', 'bigg:CHORM', 'CHORISMUTPREPHENDEHYDROG-MONOMER', 'CHORISMUTPREPHENDEHYDROG-CPLX', 'CHORISMUTPREPHENDEHYDRAT-MONOMER', 'CHORISMUTPREPHENDEHYDRAT-CPLX', 'bigg:PTAr', 'G7288-MONOMER', 'CPLX0-7912', 'PHOSACETYLTRANS-MONOMER', 'PHOSACETYLTRANS-CPLX', 'bigg:CHORS', 'AROC-MONOMER', 'AROC-CPLX', 'bigg:IGPS', 'PRAI-IGPS', 'bigg:ACKr', 'GARTRANSFORMYL2-MONOMER', 'ACETATEKINA-MONOMER', 'bigg:LEUTAi', 'TYRB-MONOMER', 'TYRB-DIMER', 'bigg:ENO', 'ENOLASE-MONOMER', 'ENOLASE-CPLX', 'bigg:FBA', 'FRUCBISALD-CLASSI-MONOMER', 'FRUCBISALD-CLASSI', 'FRUCTBISALD-CLASSII-MONOMER', 'FRUCBISALD-CLASSII', 'bigg:HCO3E', 'CARBODEHYDRAT-MONOMER', 'CARBODEHYDRAT-CPLX', 'EG12319-MONOMER', 'CPLX0-7521', 'bigg:IMPC', 'AICARTRANSIMPCYCLO-CPLX', 'bigg:IMPD', 'IMP-DEHYDROG-MONOMER', 'IMP-DEHYDROG-CPLX', 'bigg:PPS', 'PEPSYNTH-MONOMER', 'PEPSYNTH-CPLX', 'bigg:PGI', 'PGLUCISOM', 'CPLX0-7877', 'G7463-MONOMER', 'CPLX-8401', 'bigg:PGK', 'PGK', 'bigg:PGL', '6PGLUCONOLACT-MONOMER', 'bigg:RPE', 'RIBULP3EPIM-MONOMER', 'bigg:DHQTi', 'AROD-MONOMER', 'AROD-CPLX', 'bigg:IPMD', 'G6986-MONOMER', '3-ISOPROPYLMALDEHYDROG-MONOMER', '3-ISOPROPYLMALDEHYDROG-CPLX', 'bigg:AIRC3', 'PURE-MONOMER', 'PURE-CPLX', 'bigg:TALA', 'TRANSALDOLA-MONOMER', 'TRANSALDOLB-MONOMER', 'TRANSALDOLB-CPLX', 'bigg:ADSL2r', 'ASL-MONOMER', 'CPLX0-7959', 'bigg:TKT1', 'TRANSKETOII-MONOMER', 'CPLX0-1261', 'TRANSKETOI-MONOMER', 'TRANSKETOI-CPLX', 'bigg:RNDR1', 'NRDA-MONOMER', 'B1-CPLX', 'NRDB-MONOMER', 'B2-CPLX', 'RIBONUCLEOSIDE-DIP-REDUCTI-CPLX', 'bigg:ALCD2x', 'ADHP-MONOMER', 'CPLX0-8015', 'bigg:RNDR3', 'bigg:RNDR4', 'bigg:TMDS', 'THYMIDYLATESYN-MONOMER', 'THYMIDYLATESYN-CPLX', 'bigg:DHAD1', 'bigg:IPPMIa', 'bigg:MDH', 'MALATE-DEHASE-MONOMER', 'MALATE-DEHA ...

# %% [markdown]
# In the graph, every node is assigned a unique identifier. For example, reactions nodes are named via the same BIGG identifiers used in the stoichiometric model (e.g. `bigg:NDPK5` corresponds to the `NDPK5` reaction in the COBRA model). Since the graph data was largely parsed from EcoCyc, protein nodes are, for simplicity, named as their EcoCyc ID (e.g. `ADENYL-KIN-MONOMER`), but note that these IDs are intended to be internal identifiers and not used as annotations to external databses (as will see, databse annotations are available as node attributes, whenever applicable). Finally, genes are named after their b-number (e.g. `b2316`).
#
# Each node in the graph, come with a collection of attributes. We can inspect these by looking up a node using square brackets notation, which will return a dictionary of attributes/values pairs:

# %%
ich360_graph.nodes['ISOCITHASE-CPLX']
# Out:
# {'type': 'protein',
#  'subtype': 'multimeric_protein',
#  'biocyc_id': 'ECOLI:ISOCITHASE-CPLX',
#  'mw': 91.514008}

# %%
[edge for edge in ich360_graph.edges if ich360_graph.edges[edge]['type']=='logic_operator']
# Out:
# []

# %% [markdown]
# All nodes in the graph have a a `type` attribute (for example, `reaction`, `protein`,`gene` or `compound`), corresponding to the biological entity they represent, and, whenever applicable, an annotation to the biocyc databse (`biocyc_id`). In addition, `protein` nodes are further annotated with a subtype (`polypeptide`,`multimeric_protein`, or `modified_protein`) a molecular weight (`mw`, in kDa). These attributes can be used to perform arbitrary filtering queries in the graph. For example:

# %%
#identify all protein nodes
protein_nodes=[node for node in ich360_graph.nodes if ich360_graph.nodes[node]['type']=='protein']
#Identify all polypeptides
polypeptide_nodes=[node for node in ich360_graph.nodes if ich360_graph.nodes[node]['type']=='protein' and ich360_graph.nodes[node]['subtype']=='polypeptide']
#Identify all nodes, excluding genes
all_but_genes=[node for node in ich360_graph.nodes if ich360_graph.nodes[node]['type']!='gene']
#Identify all proteins with Molecular weight above 500 kDa
heavy_proteins=[node for node in ich360_graph.nodes if ich360_graph.nodes[node]['type']=='protein' and ich360_graph.nodes[node]['mw']>500]

#----------------
print(f"Found {len(protein_nodes)} nodes of type protein in the graph")
print(f"Found {len(polypeptide_nodes)} polypeptide nodes in the graph")
print(f"Found {len(all_but_genes)} nodes that are not genes in the graph")
print(f"Found {len(heavy_proteins)} protein nodes with annotated molecular weight greater than 500 kDa")
# Out:
# Found 589 nodes of type protein in the graph
# Found 360 polypeptide nodes in the graph
# Found 1302 nodes that are not genes in the graph
# Found 13 protein nodes with annotated molecular weight greater than 500 kDa

# %% [markdown]
# Among all proteins, a wide range of external annotations (as parsed from EcoCyc) are typivally availale for polypeptides nodes. These are pooled under the `annotation` attribute:

# %%
ich360_graph.nodes['PGLUCISOM']
# Out:
# {'type': 'protein',
#  'subtype': 'polypeptide',
#  'biocyc_id': 'ECOLI:PGLUCISOM',
#  'annotation': {'INTERPRO': 'IPR001672',
#   'ALPHAFOLD': 'P0A6T1',
#   'PFAM': 'PF00342',
#   'SMR': 'P0A6T1',
#   'DIP': 'DIP-35887N',
#   'PROSITE': 'PS00765',
#   'PDB': '3NBU',
#   'PRIDE': 'P0A6T1',
#   'PANTHER': 'PTHR11469',
#   'PRINTS': 'PR00662',
#   'PRODB': 'PRO_000025181',
#   'ECOLIWIKI': 'b4025',
#   'MODBASE': 'P0A6T1',
#   'SWISSMODEL': 'P0A6T1',
#   'UNIPROT': 'P0A6T1',
#   'REFSEQ': 'NP_418449'},
#  'mw': 61.530003}

# %% [markdown]
# ## Inspecting edges and their attributes
# Nodes in the graph are connceted to each other via functional relationships. These relationships (or *edges*, as they are often called in graph theory) are directional (i.e. they are characterised by a parent and a child node) and have, similarly to nodes, a well defined type. For example, we can inspect the edges associated with a node by running:

# %%
my_edges=ich360_graph.edges('ISOCITHASE-CPLX')
my_edges
# Out:
# OutEdgeDataView([('ISOCITHASE-CPLX', 'ISOCITDEH-SUBUNIT')])

# %% [markdown]
# In this case, we cans see that the node `ISOCITHASE-CPLX` has a single (outward) edge targeting the node `ISOCITDEH-SUBUNIT`. Similarly to before, we can find out more about an edge by looking it up in the graph with square bracket notation. However, edges in the graph are not associated to an ID, but are instead identified by the parent-child node pair they are associated with:

# %%
ich360_graph.edges['ISOCITHASE-CPLX','ISOCITDEH-SUBUNIT']
# Out:
# {'weight': 2,
#  'type': 'subunit_composition',
#  'subtype': 'requirement',
#  'notes': '',
#  'references': ''}

# %% [markdown]
# As their name may suggest, these nodes are connected by a `subunit_composition` relationship, indicateing that the child node (`ISOCITDEH-SUBUNIT`) is a protein subunit of the parent node (`ISOCITHASE-CPLX`). Some edge types, like this one, have a `weight` which, in this case, represent the stoichiometry of the subunit in the complex. Some nodes may be associated to multiple edges. For example a reaction may be associated to multiple catalytic edges, implying that there are multiple isoenzymes that are able catalyze it:

# %%
edges=ich360_graph.edges('bigg:MALS')
for edge in edges:
    print(f"{edge[0]}  ---{ich360_graph.edges[edge]['type']}--->  {edge[1]}")
# Out:
# bigg:MALS  ---catalysis--->  MALSYNG-MONOMER
# bigg:MALS  ---catalysis--->  MALATE-SYNTHASE

# %% [markdown]
# Similarly, a modified protein can be associacted to its unmodified form by a `protein_modification` edge, and to another protein, such as an activator, via a `protein_modification_requirement` edge:

# %%
edges=ich360_graph.edges('PYRUVFORMLY-CPLX')
for edge in edges:
    print(f"{edge[0]} ---{ich360_graph.edges[edge]['type']}--->  {edge[1]}")
# Out:
# PYRUVFORMLY-CPLX ---protein_modification--->  PYRUVFORMLY-INACTIVE-CPLX
# PYRUVFORMLY-CPLX ---protein_modification_requirement--->  PFLACTENZ-MONOMER

# %% [markdown]
# ## More advanced querying

# %% [markdown]
# Having investigate nodes and edges individually, let's now look at some slighlty more involved examples of information querying from the graph. For this purpuse, we are going to use a number of NetworkX built-in functions taylord for graph analysis.

# %%
reaction_node='bigg:MCOATA'
enzyme_node='MALATE-SYNTHASE'
# Get all children of a node, i.e. all nodes receiving an edge from that node, using the successors() method
children_nodes=ich360_graph.successors(reaction_node)
# Get all catalytic children nodes, i.e. all isoenzymes for a reaction
catalytic_children=[child for child in ich360_graph.successors(reaction_node)
                    if ich360_graph.edges[reaction_node,child]['type']=='catalysis'
                    ]

#get all parents of a node, i.e. all nodes sending an edge to this node, using the predecessors() method
parent_nodes=ich360_graph.predecessors(enzyme_node)
# Get all annotated small molecule regulators of an enzyme
regulators=[child for child in ich360_graph.predecessors(enzyme_node)
            if ich360_graph.edges[child,enzyme_node]['type'] in ['regulation']
            ]

#---------
print(f"Reaction node {reaction_node} has the following children in the graph: {list(children_nodes)}")
print(f"Of these, the following are related to {reaction_node} via a catalytic relationship: {catalytic_children}")
print()
print(f"Protein node {enzyme_node} has the following parents: {list(parent_nodes)}")
print(f"Of these, the following are related to {enzyme_node} via a regulation edge: {regulators}")
# Out:
# Reaction node bigg:MCOATA has the following children in the graph: ['MALONYL-COA-ACP-TRANSACYL-MONOMER', 'ACP-MONOMER']
# Of these, the following are related to bigg:MCOATA via a catalytic relationship: ['MALONYL-COA-ACP-TRANSACYL-MONOMER']
#
# Protein node MALATE-SYNTHASE has the following parents: ['bigg:MALS', 'PYRUVATE', 'OXALATE']
# Of these, the following are related to MALATE-SYNTHASE via a regulation edge: ['PYRUVATE', 'OXALATE']

# %% [markdown]
# ## Creating subgraphs
# So far, we have been looking at relationships in the graph between connected nodes. But what if we wanted to inspect all nodes related to another, both directly or indirectly (through other nodes). For example, we may want to extract from the graph the information related to a given reaction. Luckily for us, structuring this information in a graph format means that many common operation, such as this one, have already been implemented in packages such as NetworkX. In this case, we will use the `node_connected_component()` method of NetworkX to obtain all nodes connected to reaction. Since the annotated small molecule regulation interaction can be very promiscuous and create a temporary copy of the graph that ommits them for now. For example, let's look at the subgraph related to the `bigg:GLUDy` reaction node:

# %%
#make a temporary copy of the graph
temp_graph=ich360_graph.copy()
#Remove regulation edges to simplify the subgraph
temp_graph.remove_edges_from([edge for edge in ich360_graph.edges if ich360_graph.edges[edge]['type']=='regulation'])
#Generate a list of all nodes connected (directly or indirectly) to the reaction of interest. Note that we convert the graph to undirected form before passing it to this function
subgraph_nodes=nx.node_connected_component(temp_graph.to_undirected(),
                                        'bigg:GLUDy')
subgraph=nx.subgraph(ich360_graph,subgraph_nodes)

for edge in subgraph.edges:
    print(f"{edge[0]} ---{ich360_graph.edges[edge]['type']}--->  {edge[1]}")
# Out:
# bigg:GLUDy ---catalysis--->  GLUTAMATESYN-CPLX
# bigg:GLUDy ---catalysis--->  GDHA-CPLX
# GLUTAMATESYN-DIMER ---subunit_composition--->  GLUSYNSMALL-MONOMER
# GLUTAMATESYN-DIMER ---subunit_composition--->  GLUSYNLARGE-MONOMER
# GDHA-MONOMER ---coding_relation--->  b1761
# GDHA-CPLX ---subunit_composition--->  GDHA-MONOMER
# GLUTAMATESYN-CPLX ---subunit_composition--->  GLUTAMATESYN-DIMER
# GLUSYNLARGE-MONOMER ---coding_relation--->  b3212
# bigg:GLUSy ---catalysis--->  GLUTAMATESYN-CPLX
# GLUSYNSMALL-MONOMER ---coding_relation--->  b3213

# %% [markdown]
# ## Interactive visualisation with Gravis

# %% [markdown]
# While the `print` statements used above can enable us to do some quick, rough exploration of knowledge in the graph, it can become daunting to investigate larger portions of the graph, composed of many interconnectd nodes, this way. In this case, graphic visualisation of a (sub)graph could be desireble. Luckily, there are a number of tools out there designed for graph visualisation, and you can pick the one that best suits your need. Here, we demonstrate the use of `gravis` (https://github.com/robert-haas/gravis) which, among other things, integrates directly with NetworkX and provide us with an interactive visualisation that can be easily personalised with a graphical interface.
#
# For example, let's use `gravis` to visualise the subgraph we created above. We will use the `d3()` function:

# %%
gravis.d3(subgraph,graph_height=300)
# Out:
#   <style>
#     /* Main divisions */
#     #i4U6u4vBiq2Uj80Fp-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #i4U6u4vBiq2Uj80Fp-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #i4U6u4vBiq2Uj80Fp-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .i4U6u4vBiq2Uj80Fp-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i4U6u4vBiq2Uj80Fp-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i4U6u4vBiq2Uj80Fp-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i4U6u4vBiq2Uj80Fp-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i4U6u4vBiq2Uj80Fp-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .i4U6u4vBiq2Uj80Fp-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .i4U6u4vBiq2Uj80Fp-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .i4U6u4vBiq2Uj80Fp-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .i4U6u4vBiq2Uj80Fp-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .i4U6u4vBiq2Uj80Fp-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .i4U6u4vBiq2Uj80Fp-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .i4U6u4vBiq2Uj80Fp-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .i4U6u4vBiq2Uj80Fp-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .i4U6u4vBiq2Uj80Fp-select:after {
#       cursor: pointer;
#     }
#     .i4U6u4vBiq2Uj80Fp-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .i4U6u4vBiq2Uj80Fp-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .i4U6u4vBiq2Uj80Fp-button:active {
#       background-color: #ddd;
#     }
#     .i4U6u4vBiq2Uj80Fp-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #i4U6u4vBiq2Uj80Fp-graph-select-div {
#       display: none;
#     }
#     #i4U6u4vBiq2Uj80Fp-node-size-norm-div {
#       display: none;
#     }
#     #i4U6u4vBiq2Uj80Fp-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #i4U6u4vBiq2Uj80Fp-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-menu-toggle-button, #i4U6u4vBiq2Uj80Fp-details-toggle-button, #i4U6u4vBiq2Uj80Fp-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i4U6u4vBiq2Uj80Fp-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #i4U6u4vBiq2Uj80Fp-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #i4U6u4vBiq2Uj80Fp-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# You can call `help(gravis.d3)` to get information about the (many) plotting parameters you can set.
#
# Currently, all nodes and edges are plotted the same color, but it would be nice to show different node types with different colors. To decide on the color of a node, gravis looks for a `color` attribute in the node, and uses black if no such attribute is found. Hence, to plot different node types with different colors, we simply need to manually specify this attribute in each node (note that the same applies for edge colouring).
#
# Let's define a colormap mapping each node type (or subtype) to a desired color and then use it to annotate nodes in the graph with their desired plot colour:

# %%
#Define colormap for plotting 
nodes_colormap={'reaction':'red',
                'protein':{'multimeric_protein':'blue',
                            'modified_protein':'yellow',
                            'polypeptide':'lightblue'},
                'gene':'green',
                'compound':'gray',
                'logical_OR':'pink',
                'spontaneous':'black'}

#Now annotate each node with a "color" attribute, using the above map
for node_id in subgraph.nodes:
    node_type=subgraph.nodes[node_id]['type'] 
    if node_type=='protein':
        #If the node is a protein, we choose a color depending on the protein subtype
        protein_subtype=subgraph.nodes[node_id]['subtype']
        subgraph.nodes[node_id]['color']=nodes_colormap['protein'][protein_subtype]
    else:
        #We simply choose the color for this node type from the colormap
        subgraph.nodes[node_id]['color']=nodes_colormap[node_type]

# Plot the graph again, now with different colours for different node types
gravis.d3(subgraph,
          graph_height=300)
# Out:
#   <style>
#     /* Main divisions */
#     #iOHIrUbkatMdRw9Cv-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iOHIrUbkatMdRw9Cv-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iOHIrUbkatMdRw9Cv-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iOHIrUbkatMdRw9Cv-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iOHIrUbkatMdRw9Cv-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iOHIrUbkatMdRw9Cv-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iOHIrUbkatMdRw9Cv-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iOHIrUbkatMdRw9Cv-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iOHIrUbkatMdRw9Cv-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iOHIrUbkatMdRw9Cv-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iOHIrUbkatMdRw9Cv-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iOHIrUbkatMdRw9Cv-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iOHIrUbkatMdRw9Cv-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iOHIrUbkatMdRw9Cv-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iOHIrUbkatMdRw9Cv-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iOHIrUbkatMdRw9Cv-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iOHIrUbkatMdRw9Cv-select:after {
#       cursor: pointer;
#     }
#     .iOHIrUbkatMdRw9Cv-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iOHIrUbkatMdRw9Cv-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iOHIrUbkatMdRw9Cv-button:active {
#       background-color: #ddd;
#     }
#     .iOHIrUbkatMdRw9Cv-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iOHIrUbkatMdRw9Cv-graph-select-div {
#       display: none;
#     }
#     #iOHIrUbkatMdRw9Cv-node-size-norm-div {
#       display: none;
#     }
#     #iOHIrUbkatMdRw9Cv-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iOHIrUbkatMdRw9Cv-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-menu-toggle-button, #iOHIrUbkatMdRw9Cv-details-toggle-button, #iOHIrUbkatMdRw9Cv-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iOHIrUbkatMdRw9Cv-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iOHIrUbkatMdRw9Cv-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iOHIrUbkatMdRw9Cv-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# Success! As a last thing, let's also visualise edge types as labels over the edges. To do this,  we set `show_edge_label=True` and `edge_label_data_source` to the attribute we'd like to use as a label, in this case the `type` attribute. Tuning the `many_body_force_strength` parameters will also help distancing nodes from each other (negative values correspond to repulsion between nodes).

# %%
#Plot graph again, showing the edge type as a label over each edge
gravis.d3(subgraph,
          graph_height=450,
          show_edge_label=True,
          edge_label_data_source='type',
          many_body_force_strength=-300
         )
# Out:
#   <style>
#     /* Main divisions */
#     #i2tVRZpu4y6yaN3Dz-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #i2tVRZpu4y6yaN3Dz-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #i2tVRZpu4y6yaN3Dz-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .i2tVRZpu4y6yaN3Dz-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i2tVRZpu4y6yaN3Dz-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i2tVRZpu4y6yaN3Dz-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i2tVRZpu4y6yaN3Dz-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .i2tVRZpu4y6yaN3Dz-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .i2tVRZpu4y6yaN3Dz-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .i2tVRZpu4y6yaN3Dz-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .i2tVRZpu4y6yaN3Dz-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .i2tVRZpu4y6yaN3Dz-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .i2tVRZpu4y6yaN3Dz-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .i2tVRZpu4y6yaN3Dz-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .i2tVRZpu4y6yaN3Dz-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .i2tVRZpu4y6yaN3Dz-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .i2tVRZpu4y6yaN3Dz-select:after {
#       cursor: pointer;
#     }
#     .i2tVRZpu4y6yaN3Dz-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .i2tVRZpu4y6yaN3Dz-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .i2tVRZpu4y6yaN3Dz-button:active {
#       background-color: #ddd;
#     }
#     .i2tVRZpu4y6yaN3Dz-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #i2tVRZpu4y6yaN3Dz-graph-select-div {
#       display: none;
#     }
#     #i2tVRZpu4y6yaN3Dz-node-size-norm-div {
#       display: none;
#     }
#     #i2tVRZpu4y6yaN3Dz-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #i2tVRZpu4y6yaN3Dz-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-menu-toggle-button, #i2tVRZpu4y6yaN3Dz-details-toggle-button, #i2tVRZpu4y6yaN3Dz-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #i2tVRZpu4y6yaN3Dz-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #i2tVRZpu4y6yaN3Dz-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #i2tVRZpu4y6yaN3Dz-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none

# %% [markdown]
# If you wanted to include edge subtypes in the labels (for those edge types where this is applicable), you could just create a new attribute for each edge, obtained by merging the edge type and subtype strings, and specify that as the desired `edge_label_data_source`.

# %% [markdown]
# That's it for now! Make sure to look in the docs for NetworkX (https://networkx.org/documentation/stable/) and gravis (https://robert-haas.github.io/gravis-docs/) to learn more about the many ways you have to embed the *i*CH360 knowledge graph in your pipelines. To conclude, here is a visualisation of the enture graph (once again, omitting small molecule regulation to streamline visualisation):

# %%
#Annotate the graph with colors
for node_id in ich360_graph.nodes:
    node_type=ich360_graph.nodes[node_id]['type'] 
    if node_type=='protein':
        #If the node is a protein, we choose a color depending on the protein subtype
        protein_subtype=ich360_graph.nodes[node_id]['subtype']
        ich360_graph.nodes[node_id]['color']=nodes_colormap['protein'][protein_subtype]
    else:
        #We simply choose the color for this node type from the colormap
        ich360_graph.nodes[node_id]['color']=nodes_colormap[node_type]

#Remove regulation edges to simplify visualisation
full_graph_wo_regulation=ich360_graph.copy()
full_graph_wo_regulation.remove_edges_from([edge for edge in ich360_graph.edges if ich360_graph.edges[edge]['type']=='regulation'])

#Plot
gravis.d3(full_graph_wo_regulation,
          graph_height=1000,
          zoom_factor=0.1
         )
# Out:
#   <style>
#     /* Main divisions */
#     #iIV2pnfG9EfUDXnuI-main-div {
#       line-height: normal;
#       box-sizing: content-box;
#       padding: 3px;
#       background-color: white;
#     }
#     #iIV2pnfG9EfUDXnuI-left-div {
#       float: left;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-right-div {
#       float: left;
#       height: 100%;
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-right-inner-div {
#       padding-left: 5px;
#       padding-right: 2px;
#       overflow-x: hidden;
#       overflow-y: auto;
#       height: 100%;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Graph and details (contained in left-inner-div) */
#     #iIV2pnfG9EfUDXnuI-graph-div {
#       overflow: hidden;
#       resize: vertical;
#       position: relative;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-details-div {
#       overflow: auto;
#       resize: vertical;
#       margin-top: 5px;
#       border: 1px solid #ccc;
#       border-radius: 4px;
#       box-shadow: 0px 0px 2px rgba(0, 0, 0, 0.2);
#       display: none;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-details-head {
#       user-select: none;
#       padding-left: 4px !important;
#       padding-top: 4px !important;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: gray;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-details-body {
#       padding: 10px;
#       padding-top: 6px;
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#
#     /* Control menu (contained in right-inner-div) */
#     .iIV2pnfG9EfUDXnuI-menu-item-head {
#       font-size: 11px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       cursor: pointer;
#       padding-left: 5px;
#       padding-right: 0px;
#       padding-top: 5px;
#       padding-bottom: 5px;
#       margin-bottom: 5px;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 3px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iIV2pnfG9EfUDXnuI-menu-item-body {
#       margin-left: 5px;
#       margin-bottom: 10px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iIV2pnfG9EfUDXnuI-menu-subitem-head {
#       font-size: 9px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-weight: 600;
#       color: #006429;
#       cursor: default;
#       margin-bottom: 2px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iIV2pnfG9EfUDXnuI-menu-subitem-body {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       margin-left: 7px;
#       margin-bottom: 5px;
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     .iIV2pnfG9EfUDXnuI-labeled-input {
#       all: initial;
#       display: flex;
#       align-items: center;
#       margin-top: 1px;
#       margin-bottom: 1px;
#     }
#     .iIV2pnfG9EfUDXnuI-label {
#       all: initial;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       cursor: pointer;
#     }
#     .iIV2pnfG9EfUDXnuI-slider {
#       width: 100%;
#       margin-bottom: 2px;
#     }
#     .iIV2pnfG9EfUDXnuI-slider::-moz-focus-outer {
#       border: 0;
#     }
#     .iIV2pnfG9EfUDXnuI-slider-text-left {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       font-style: italic;
#       color: black;
#       float: left;
#       margin-top: 2px;
#     }
#     .iIV2pnfG9EfUDXnuI-slider-text-right {
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       float: right;
#     }
#     .iIV2pnfG9EfUDXnuI-checkbox {
#       margin-left: 0px !important;
#       margin-right: 4px !important;
#       margin-top: 2px !important;
#       margin-bottom: 2px !important;
#       padding: 0px !important;
#     }
#     .iIV2pnfG9EfUDXnuI-select {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f5f5f5;
#       width: 100%;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 5px;
#       padding-right: 10px;
#       margin-right: 5px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#
#       -moz-appearance: none;
#       -webkit-appearance: none;
#       appearance: none;
#       background-image: url('...');
#       background-repeat: no-repeat;
#       background-position: right 4px top 50%;
#       background-size: 6px;
#     }
#     @-moz-document url-prefix() {
#       /* Dirty hack to remove dotted border on focus */
#       .iIV2pnfG9EfUDXnuI-select {
#         color: transparent !important;
#         text-shadow: 0 0 0 black !important;
#       }
#     }
#     .iIV2pnfG9EfUDXnuI-select:after {
#       cursor: pointer;
#     }
#     .iIV2pnfG9EfUDXnuI-button {
#       cursor: pointer;
#       outline: none;
#       font-size: 8px;
#       font-family: "Lucida Console", Monaco, monospace;
#       color: black;
#       background-color: #f2f2f2;
#       padding-top: 4px !important;
#       padding-bottom: 4px !important;
#       padding-left: 10px;
#       padding-right: 10px;
#       margin-top: 2px;
#       margin-bottom: 2px;
#       border-radius: 4px;
#       border: 1.2px solid #bbb;
#       box-shadow: 0 1px 0 1px rgba(0, 0, 0, 0.04);
#     }
#     .iIV2pnfG9EfUDXnuI-button:hover {
#       border: 1.2px solid #999;
#       background-color: #f2f2f2;
#     }
#     .iIV2pnfG9EfUDXnuI-button:active {
#       background-color: #ddd;
#     }
#     .iIV2pnfG9EfUDXnuI-button::-moz-focus-inner {
#       border: 0;
#     }
#     /* Hidden menu items */
#     #iIV2pnfG9EfUDXnuI-graph-select-div {
#       display: none;
#     }
#     #iIV2pnfG9EfUDXnuI-node-size-norm-div {
#       display: none;
#     }
#     #iIV2pnfG9EfUDXnuI-edge-size-norm-div {
#       display: none;
#     }
#
#     /* Graph */
#     #iIV2pnfG9EfUDXnuI-tooltip-div {
#       font-size: 10px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42001;
#       opacity: 0;
#       visibility: hidden;
#       position: absolute !important;
#       max-width: 40%;
#       padding: 5px;
#       white-space: pre-wrap;
#       word-break: break-word;
#       color: black;
#       background-color: white;
#       border-radius: 4px;
#       border: 1px solid #ccc;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-menu-toggle-button, #iIV2pnfG9EfUDXnuI-details-toggle-button, #iIV2pnfG9EfUDXnuI-progress-container {
#       font-size: 14px;
#       font-family: "Lucida Console", Monaco, monospace;
#       z-index: 42000;
#       cursor: pointer;
#       position: absolute;
#       background-color: white;
#       border-radius: 4px;
#       box-shadow: 0px 0px 4px rgba(0, 0, 0, 0.2);
#       line-height: normal;
#       box-sizing: content-box;
#     }
#     #iIV2pnfG9EfUDXnuI-menu-toggle-button {
#       top: 0;
#       right: 0;
#       padding-left: 6px;
#       padding-right: 6px;
#       padding-top: 12px;
#       padding-bottom: 12px;
#       border-top: 0px;
#       border-right: 0px;
#       border-bottom: 1px solid #ccc;
#       border-left: 1px solid #ccc;
#     }
#     #iIV2pnfG9EfUDXnuI-details-toggle-button {
#       bottom: 0;
#       left: 0;
#       padding-left: 19px;
#       padding-right: 19px;
#       padding-top: 0.5px;
#       padding-bottom: 2px;
#       border-top: 1px solid #ccc;
#       border-right: 1px solid #ccc;
#       border-bottom: 0px;
#       border-left: 0px;
#     }
#     #iIV2pnfG9EfUDXnuI-progress-container {
#       font-size: 10px;
#       text-align: center;
#       top: 46%;
#       left: 15%;
#       width: 70%;
#       padding: 8px;
#       border: none
